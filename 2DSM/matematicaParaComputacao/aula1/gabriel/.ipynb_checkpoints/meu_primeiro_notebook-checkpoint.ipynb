# %%
# Meu primeiro notebook

print("Meu nome é gabriel")
# Out:
# Meu nome é gabriel

# %%
from matplotlib import pyplot as plt
import numpy as np
import math

x = np.linspace(-5,5,100)
senvec = np.vectorize(math.sin)
y = senvec(x)
plt.plot(x,y)
plt.show()
